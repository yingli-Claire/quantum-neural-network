# %%
from qiskit import QuantumCircuit, Aer
from qiskit.visualization import plot_state_city

# %%
circuit = QuantumCircuit(2)

circuit.h(0)
circuit.h(1)

backend = Aer.get_backend('statevector_simulator')
job = backend.run(circuit)
result = job.result()
state = result.get_statevector(circuit, decimals=2)
print(state)

plot_state_city(state)
# Out:
# Statevector([0.5+0.j, 0.5+0.j, 0.5+0.j, 0.5+0.j],
#             dims=(2, 2))

# %% [markdown]
# $ \frac{\ket{000} + \ket{111}  }{\sqrt2}  $

# %%
circuit = QuantumCircuit(3)

circuit.h(0)
circuit.cx(0, 1)
circuit.cx(0, 2)

circuit.draw('mpl')

backend = Aer.get_backend('statevector_simulator')
job = backend.run(circuit)
result = job.result()
state = result.get_statevector(circuit, decimals=3)
print(state)
plot_state_city(state)
# Out:
# /gpfs/share/home/1601110140/software/anaconda3/envs/pytorch/lib/python3.10/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)
# Statevector([0.707+0.j, 0.   +0.j, 0.   +0.j, 0.   +0.j, 0.   +0.j,
#              0.   +0.j, 0.   +0.j, 0.707+0.j],
#             dims=(2, 2, 2))

# %%
circuit = QuantumCircuit(3)

circuit.h(0)
circuit.cx(0, 1)
circuit.cx(0, 2)
circuit.measure_all()
circuit.draw('mpl')
# Out:
# /gpfs/share/home/1601110140/software/anaconda3/envs/pytorch/lib/python3.10/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
from qiskit import transpile
from qiskit.visualization import plot_state_city, plot_histogram

circuit = QuantumCircuit(3)

circuit.h(0)
circuit.cx(0, 1)
circuit.cx(0, 2)
circuit.measure_all()
circuit.draw('mpl')

sim = Aer.get_backend('qasm_simulator')
job = sim.run(transpile(circuit, sim), shots=1000)

counts = job.result().get_counts(circuit)
print(counts)
plot_histogram(counts)
# Out:
# {'111': 508, '000': 492}
# /gpfs/share/home/1601110140/software/anaconda3/envs/pytorch/lib/python3.10/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
from qiskit.auqa.algorithms import QAOA

algo = QAOA()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 from qiskit.auqa.algorithms import QAOA
#       3 algo = QAOA()
#
# ModuleNotFoundError: No module named 'qiskit.auqa'
